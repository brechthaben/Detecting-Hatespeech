# %% [markdown]
# # Loading Data

# %%
# Cell 1: Imports and Configuration

# Ensure the atproto library is up-to-date
# !pip install --upgrade atproto

import os
from datetime import datetime, timezone, timedelta
from atproto import Client, models
# Import FirehoseError for specific Firehose errors
# Import RequestException for general ATProto API errors
from atproto.exceptions import FirehoseError, RequestException # Corrected import

# --- Bluesky Credentials ---
# It's recommended to use Colab Secrets for credentials instead of hardcoding.
# If you comment out the Colab Secrets part in Cell 2, uncomment these:
# BLUESKY_HANDLE = os.environ.get("BLUESKY_HANDLE", "yourname.bsky.social") # REPLACE or set env var
# BLUESKY_APP_PASSWORD = os.environ.get("BLUESKY_APP_PASSWORD", "xxxx-xxxx-xxxx-xxxx") # REPLACE or set env var

# --- Analysis Parameters ---
# How many posts to try and collect that fit the criteria
TARGET_POST_COUNT = int(os.environ.get("TARGET_POST_COUNT", 50))

# Timeframe for posts (ISO 8601 format, UTC is recommended: YYYY-MM-DDTHH:MM:SSZ)
# Example: Last 7 days
default_end_time = datetime.now(timezone.utc)
# --- Widened timeframe for testing ---
# default_start_time = default_end_time - timedelta(days=7) # Original
default_start_time = default_end_time - timedelta(days=30) # Example: Last 30 days for more data

TIMEFRAME_START_ISO = os.environ.get("TIMEFRAME_START_ISO", default_start_time.isoformat().replace('+00:00', 'Z'))
TIMEFRAME_END_ISO = os.environ.get("TIMEFRAME_END_ISO", default_end_time.isoformat().replace('+00:00', 'Z'))

# The AT URI of the feed to sample from.
# "What's Hot Classic" is a good general purpose feed.
# You can find others on sites like https://skyfeed.me/feeds or by looking at feed generator DIDs.
FEED_URI_TO_QUERY = os.environ.get("FEED_URI_TO_QUERY", "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.generator/hot-classic")

# --- Safety Parameters ---
# Max number of feed pages to fetch to avoid running indefinitely
# --- Increased max pages for testing ---
# MAX_PAGES_TO_FETCH = 20 # Original
MAX_PAGES_TO_FETCH = 50 # Example: Fetch more pages

POSTS_PER_PAGE = 50 # API usually returns up to this many, can be set lower

print(f"Configuration:")
print(f"  Target post count: {TARGET_POST_COUNT}")
print(f"  Timeframe Start: {TIMEFRAME_START_ISO}")
print(f"  Timeframe End: {TIMEFRAME_END_ISO}")
print(f"  Feed URI: {FEED_URI_TO_QUERY}")
print(f"  Max pages to fetch: {MAX_PAGES_TO_FETCH}")
print(f"  Posts per page (limit): {POSTS_PER_PAGE}")
print("-" * 30)

# Helper to parse ISO string to timezone-aware datetime object
def parse_iso_datetime(iso_str: str) -> datetime | None:
    if not iso_str:
        return None
    try:
        # Python 3.11+ handles 'Z' directly. For older, replace 'Z'.
        if iso_str.endswith('Z'):
            iso_str = iso_str[:-1] + '+00:00'
        dt = datetime.fromisoformat(iso_str)
        # Ensure it's UTC if no timezone info was present but we expect UTC
        if dt.tzinfo is None:
            dt = dt.replace(tzinfo=timezone.utc)
        return dt
    except ValueError as e:
        print(f"Warning: Could not parse date '{iso_str}': {e}")
        return None

TIMEFRAME_START_DT = parse_iso_datetime(TIMEFRAME_START_ISO)
TIMEFRAME_END_DT = parse_iso_datetime(TIMEFRAME_END_ISO)

if not TIMEFRAME_START_DT or not TIMEFRAME_END_DT:
    raise ValueError("Invalid start or end datetime. Please check TIMEFRAME_START_ISO and TIMEFRAME_END_ISO.")
if TIMEFRAME_START_DT >= TIMEFRAME_END_DT:
    raise ValueError("TIMEFRAME_START_DT must be before TIMEFRAME_END_DT.")
# Out:
# Requirement already satisfied: atproto in /usr/local/lib/python3.11/dist-packages (0.0.61)
# Requirement already satisfied: click<9,>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from atproto) (8.2.1)
# Requirement already satisfied: cryptography<46,>=41.0.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (43.0.3)
# Requirement already satisfied: dnspython<3,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (2.7.0)
# Requirement already satisfied: httpx<0.29.0,>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (0.28.1)
# Requirement already satisfied: libipld<4,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from atproto) (3.1.0)
# Requirement already satisfied: pydantic<3,>=2.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (2.11.7)
# Requirement already satisfied: typing-extensions<5,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (4.14.0)
# Requirement already satisfied: websockets<14,>=12 in /usr/local/lib/python3.11/dist-packages (from atproto) (13.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<46,>=41.0.7->atproto) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.29.0,>=0.25.0->atproto) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.29.0,>=0.25.0->atproto) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.29.0,>=0.25.0->atproto) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.29.0,>=0.25.0->atproto) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.29.0,>=0.25.0->atproto) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (0.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<46,>=41.0.7->atproto) (2.22)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<0.29.0,>=0.25.0->atproto) (1.3.1)
# Configuration:
#   Target post count: 50
#   Timeframe Start: 2025-05-24T09:40:22.485798Z
#   Timeframe End: 2025-06-23T09:40:22.485798Z
#   Feed URI: at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.generator/hot-classic
#   Max pages to fetch: 50
#   Posts per page (limit): 50
# ------------------------------

# %%
# Cell 2: Login to Bluesky
from google.colab import userdata
from atproto.exceptions import RequestException # Changed AtprotoError to RequestException

# Retrieve credentials from Colab Secrets
try:
    BLUESKY_HANDLE = userdata.get('BLUESKY_HANDLE')
    BLUESKY_APP_PASSWORD = userdata.get('BLUESKY_APP_PASSWORD')

    print(f"Retrieved HANDLE: {BLUESKY_HANDLE}") # Debug print
    print(f"Retrieved APP_PASSWORD: {'*' * len(BLUESKY_APP_PASSWORD) if BLUESKY_APP_PASSWORD else 'None'}") # Debug print (don't print the actual password)


    if not BLUESKY_HANDLE or not BLUESKY_APP_PASSWORD:
        raise ValueError("Bluesky credentials not found or empty in Colab Secrets.")

    client = Client()
    print(f"Attempting to log in as {BLUESKY_HANDLE} using Colab Secrets...")
    # The login method itself can raise atproto.exceptions.RequestException
    profile = client.login(BLUESKY_HANDLE, BLUESKY_APP_PASSWORD)
    print(f"Successfully logged in as {profile.handle} (DID: {profile.did})")

except RequestException as e: # Changed AtprotoError to RequestException
    print(f"Bluesky API Login Failed: {e}") # Specific API error
    client = None # Ensure client is None on failure

except Exception as e:
    print(f"General Login failed: {e}") # Other exceptions
    print("Ensure 'BLUESKY_HANDLE' and 'BLUESKY_APP_PASSWORD' are set in Colab Secrets.")
    print("Or comment out the login block if targeting a public feed anonymously.")
    client = None # Ensure client is None on failure

# Add a print statement after the try...except block to see the final client state
print(f"Client object after login attempt: {client}")
# Out:
# Retrieved HANDLE: dp2project.bsky.social
# Retrieved APP_PASSWORD: *******************
# Attempting to log in as dp2project.bsky.social using Colab Secrets...
# Successfully logged in as dp2project.bsky.social (DID: did:plc:in6rgxlucspbkpnw22634urd)
# Client object after login attempt: <atproto_client.client.client.Client object at 0x799b0670d050>

# %%
# Cell 3: Helper function to parse post data
def parse_post_view_data(post_view: models.AppBskyFeedDefs.PostView):
    """Extracts content and date from a PostView model."""
    content = ""
    created_at_str = ""
    author_did = post_view.author.did
    author_handle = post_view.author.handle

    try:
        if isinstance(post_view.record, models.AppBskyFeedPost.Record):
            content = post_view.record.text
            created_at_str = post_view.record.created_at
        elif isinstance(post_view.record, dict): # Fallback for unexpected record types
            content = post_view.record.get('text', '')
            created_at_str = post_view.record.get('createdAt', '') # ATProto spec uses createdAt
        else:
            # Handle cases where the record is of an unexpected type
            print(f"Warning: Encountered unexpected post record type for URI {post_view.uri}: {type(post_view.record)}")
            return None # Skip this post if the record is not a standard post type

        parsed_date = parse_iso_datetime(created_at_str)
        if parsed_date is None:
             print(f"Warning: Skipping post {post_view.uri} due to unparseable date: '{created_at_str}'")
             return None # Skip if date cannot be parsed

        return {
            "uri": post_view.uri,
            "cid": post_view.cid,
            "author_did": author_did,
            "author_handle": author_handle,
            "content": content,
            "created_at_iso": created_at_str, # Store original string
            "created_at_dt": parsed_date,   # Store parsed datetime object
            "reply_count": post_view.reply_count if post_view.reply_count is not None else 0,
            "repost_count": post_view.repost_count if post_view.repost_count is not None else 0,
            "like_count": post_view.like_count if post_view.like_count is not None else 0,
        }
    except Exception as e:
        print(f"Error parsing post {post_view.uri if hasattr(post_view, 'uri') else 'N/A'}: {e}")
        return None # Return None if any error occurs during parsing

# %%

# %%
# Cell 4: Fetching and Filtering Posts

def get_posts_from_feed_in_timeframe(
    client: Client,
    feed_uri: str,
    start_dt: datetime,
    end_dt: datetime,
    target_count: int,
    posts_per_page: int = 50, # How many posts to request per API call
    max_pages: int = 50       # Safety limit for number of pages
):
    """
    Fetches posts from a given feed URI that fall within a specified timeframe.

    Args:
        client: Authenticated atproto.Client instance.
        feed_uri: The AT URI of the feed to fetch (e.g., "What's Hot Classic").
        start_dt: The start of the desired timeframe (timezone-aware datetime).
        end_dt: The end of the desired timeframe (timezone-aware datetime).
        target_count: The desired number of posts to collect.
        posts_per_page: Number of posts to fetch in each API request.
        max_pages: Maximum number of pages to fetch to prevent infinite loops.

    Returns:
        A list of post data dictionaries.
    """
    collected_posts = []
    cursor = None
    pages_fetched = 0

    print(f"Fetching posts from feed: {feed_uri}")
    print(f"Looking for posts between {start_dt.isoformat()} and {end_dt.isoformat()}")

    while len(collected_posts) < target_count and pages_fetched < max_pages:
        try:
            print(f"Fetching page {pages_fetched + 1} (cursor: {cursor})...")
            # Construct the params object
            params = models.AppBskyFeedGetFeed.Params(
                feed=feed_uri,
                limit=posts_per_page,
                cursor=cursor
            )
            # Pass the params object to the get_feed method
            response = client.app.bsky.feed.get_feed(params)

        except RequestException as e:
            print(f"API Error fetching feed page {pages_fetched + 1}: {e}")
            # Decide if you want to retry or break on specific errors
            break # Break on API errors

        except Exception as e:
            print(f"Unexpected error fetching feed page {pages_fetched + 1}: {e}")
            break # Break on other unexpected errors


        if not response or not response.feed:
            print("No more posts in the feed or empty response for this page.")
            if pages_fetched == 0:
                print("Consider widening the timeframe or checking the feed URI.")
            break

        posts_on_page_in_timeframe = 0
        for feed_view_post in response.feed:
             # Ensure we are processing a standard PostView and it has a post attribute
            if not isinstance(feed_view_post, models.AppBskyFeedDefs.FeedViewPost) or not hasattr(feed_view_post, 'post'):
                 # print(f"Skipping item of unexpected type: {type(feed_view_post)}")
                 continue # Skip items that aren't standard feed view posts with a 'post' field

            post_data = parse_post_view_data(feed_view_post.post)

            if post_data: # Check if parsing was successful and returned data
                post_date = post_data["created_at_dt"]

                # post_date is already timezone-aware from parse_iso_datetime
                if start_dt <= post_date <= end_dt:
                    collected_posts.append(post_data)
                    posts_on_page_in_timeframe += 1
                    if len(collected_posts) >= target_count:
                        break # Reached target
                # Optional: Early exit if post is much older than start date,
                # assuming feed is roughly chronological. Be cautious with this
                # on feeds like 'What's Hot' which are based on popularity.
                # elif post_date < start_dt and pages_fetched > 0:
                #     print(f"Post {post_data['uri']} ({post_date}) is older than start date {start_dt}. Considering early exit.")
                #     # A more sophisticated check might be needed here.
                #     pass # Continue fetching for now on 'What's Hot'


        print(f"  Found {posts_on_page_in_timeframe} posts in timeframe on this page.")
        print(f"  Total collected so far: {len(collected_posts)} / {target_count}")

        if len(collected_posts) >= target_count:
            print("Target number of posts collected.")
            break

        cursor = response.cursor
        if not cursor:
            print("No more pages (cursor is null).")
            break
        pages_fetched += 1

    if pages_fetched >= max_pages:
        print(f"Reached maximum page limit ({max_pages}) before collecting {target_count} posts.")
    elif len(collected_posts) < target_count:
        print(f"Finished fetching all available pages within the limit ({max_pages}), but only collected {len(collected_posts)}/{target_count} posts in the specified timeframe.")


    return collected_posts

# --- Execute the fetching ---
# Check if client is authenticated and not None after the login attempt
if 'client' in locals() and client is not None and client.me:
    try:
        sampled_posts = get_posts_from_feed_in_timeframe(
            client,
            feed_uri=FEED_URI_TO_QUERY,
            start_dt=TIMEFRAME_START_DT,
            end_dt=TIMEFRAME_END_DT,
            target_count=TARGET_POST_COUNT,
            posts_per_page=POSTS_PER_PAGE,
            max_pages=MAX_PAGES_TO_FETCH # Using the potentially increased value
        )
        print(f"\n--- Collected {len(sampled_posts)} Posts ---")
        if sampled_posts:
            for i, post in enumerate(sampled_posts):
                date_str = post['created_at_dt'].strftime('%Y-%m-%d %H:%M:%S %Z') if post['created_at_dt'] else "N/A"
                print(f"{i+1}. Author: {post['author_handle']} ({post['author_did']})")
                print(f"   Date: {date_str}")
                print(f"   Content: '{post['content'][:150].replace(chr(10), ' ')}...'") # Truncate and remove newlines for display
                print(f"   URI: {post['uri']}")
                print(f"   Likes: {post['like_count']}, Reposts: {post['repost_count']}, Replies: {post['reply_count']}")
                print("-" * 20)

            # Convert collected posts to PySpark RDD
            # This requires SparkSession to be initialized, which happens in Cell 5.
            # Ensure Cell 5 is run before this part if you intend to use Spark.
            # Checking if spark is defined to avoid NameError if Cell 5 hasn't run.
            if 'spark' in globals() and sampled_posts:
                 posts_rdd = spark.sparkContext.parallelize(sampled_posts)
                 print("\n--- RDD created from collected posts ---")
                 print(f"Number of partitions in RDD: {posts_rdd.getNumPartitions()}")

                 # You can now perform RDD operations on posts_rdd

                 # Example: Print a few elements from the RDD
                 print("\nSample RDD elements:")
                 for i, post in enumerate(posts_rdd.take(5)): # take the first 5 elements
                     print(f"  {i+1}. {post}")

            elif sampled_posts:
                 print("SparkSession not initialized. Skipping RDD creation.")

            else:
                print("No posts collected, RDD not created.")


        else:
            print("No posts collected that fit the criteria.")

    except Exception as e:
        print(f"An error occurred during the post fetching process: {e}")


else:
    print("Client not authenticated. Skipping post fetching.")
# Out:
# Fetching posts from feed: at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.generator/hot-classic
# Looking for posts between 2025-05-24T09:40:22.485798+00:00 and 2025-06-23T09:40:22.485798+00:00
# Fetching page 1 (cursor: None)...
#   Found 50 posts in timeframe on this page.
#   Total collected so far: 50 / 50
# Target number of posts collected.
#
# --- Collected 50 Posts ---
# 1. Author: aphclarkson.bsky.social (did:plc:xv2as7miy7ghje2htfynaqex)
#    Date: 2025-06-23 09:38:19 UTC
#    Content: 'If the Khamenei regime does ever fall you end up with the question of who gets there hands on 400 kilograms of 60% enriched uranium whose location in ...'
#    URI: at://did:plc:xv2as7miy7ghje2htfynaqex/app.bsky.feed.post/3lsbbwheycs2h
#    Likes: 17, Reposts: 2, Replies: 4
# --------------------
# 2. Author: austinwalker.bsky.social (did:plc:sykjce6e3ll5g6ev6evkcy3f)
#    Date: 2025-06-23 09:37:47 UTC
#    Content: 'Had a great time at @narrascope.org this weekend, and as someone recovering from painful dentist stuff, was super grateful the conference was entirely...'
#    URI: at://did:plc:sykjce6e3ll5g6ev6evkcy3f/app.bsky.feed.post/3lsbbviw4ys2w
#    Likes: 12, Reposts: 0, Replies: 0
# --------------------
# 3. Author: bernietranders.bsky.social (did:plc:hy5oozdsk27yctrzp4zuoqic)
#    Date: 2025-06-23 09:37:19 UTC
#    Content: 'Happy 30th birthday to my gorgeous husband to be, @dpdormouse.bsky.social!  Hope you have a wonderful day, looking forward to celebrating a lifetime o...'
#    URI: at://did:plc:hy5oozdsk27yctrzp4zuoqic/app.bsky.feed.post/3lsbbuoiocs2e
#    Likes: 23, Reposts: 0, Replies: 0
# --------------------
# 4. Author: hideokojima.bsky.kojimaproductions.jp (did:plc:iezr5kzha5ycldknsa3jumiy)
#    Date: 2025-06-23 09:36:47 UTC
#    Content: '...'
#    URI: at://did:plc:iezr5kzha5ycldknsa3jumiy/app.bsky.feed.post/3lsbbtpsims2j
#    Likes: 13, Reposts: 2, Replies: 1
# --------------------
# 5. Author: rajandelman.bsky.social (did:plc:zy6sn6tkic24e6p52g2yh4zn)
#    Date: 2025-06-23 09:36:45 UTC
#    Content: 'JK like, "Joke's on you, I've never had a friend, you dumb idiot"...'
#    URI: at://did:plc:zy6sn6tkic24e6p52g2yh4zn/app.bsky.feed.post/3lsbbtni4qk2e
#    Likes: 17, Reposts: 1, Replies: 0
# --------------------
# 6. Author: magencubed.bsky.social (did:plc:hgccsshlebvbixeag4td4x5y)
#    Date: 2025-06-23 09:36:36 UTC
#    Content: 'At this point, I'm choosing to find it funny that the Democratic leadership is century-old sexual predators and warhawks braying for Iranian blood who...'
#    URI: at://did:plc:hgccsshlebvbixeag4td4x5y/app.bsky.feed.post/3lsbbtfr2ik22
#    Likes: 12, Reposts: 3, Replies: 1
# --------------------
# 7. Author: teamswiftparrot.bsky.social (did:plc:3uwudujgyeqflhozfxvd4ewx)
#    Date: 2025-06-23 09:36:11 UTC
#    Content: 'Look at this phenomenal yellow-tailed black-cockatoo eating protea nectar 🙂👑...'
#    URI: at://did:plc:3uwudujgyeqflhozfxvd4ewx/app.bsky.feed.post/3lsbbsnv47c27
#    Likes: 13, Reposts: 4, Replies: 2
# --------------------
# 8. Author: isabelsantos.bsky.social (did:plc:uqnyrpls22pqbicmdkwnlvli)
#    Date: 2025-06-23 09:35:55 UTC
#    Content: 'Who in their right mind would nominate Trump for a peace prize? Peace? This man has been a chaos machine from the moment he took office—stoking divisi...'
#    URI: at://did:plc:uqnyrpls22pqbicmdkwnlvli/app.bsky.feed.post/3lsbbs67ek22y
#    Likes: 19, Reposts: 1, Replies: 2
# --------------------
# 9. Author: cadenaser.com (did:plc:cgtt2xmdufwgh6msvt7vvpg2)
#    Date: 2025-06-23 09:35:54 UTC
#    Content: 'El TSJM anula la sentencia que impedía colgar la bandera LGTBI en el edificio de grupos del Ayuntamiento de Madrid ...'
#    URI: at://did:plc:cgtt2xmdufwgh6msvt7vvpg2/app.bsky.feed.post/3lsbbs5jzzf24
#    Likes: 12, Reposts: 4, Replies: 0
# --------------------
# 10. Author: r0x0r.bsky.social (did:plc:tkz5eolt5jt53bgkg2ku27gj)
#    Date: 2025-06-23 09:35:28 UTC
#    Content: 'fine x...'
#    URI: at://did:plc:tkz5eolt5jt53bgkg2ku27gj/app.bsky.feed.post/3lsbbrej5yk2b
#    Likes: 13, Reposts: 1, Replies: 1
# --------------------
# 11. Author: brodnig.bsky.social (did:plc:7qy7aa3j7wnkvg246iokgyrm)
#    Date: 2025-06-23 09:35:18 UTC
#    Content: 'Eine Anmerkung noch: Ich halte das wirklich für falsch, dass Mitarbeiter:innen in Ministerien legal die Social-Media-Accounts von Parteien bespielen s...'
#    URI: at://did:plc:7qy7aa3j7wnkvg246iokgyrm/app.bsky.feed.post/3lsbbr367lk2b
#    Likes: 28, Reposts: 5, Replies: 1
# --------------------
# 12. Author: soapachu.bsky.social (did:plc:t4ugkdwwiy4nni4v7svyaisy)
#    Date: 2025-06-23 09:35:12 UTC
#    Content: 'Tragically, the original post got deleted. BUT......'
#    URI: at://did:plc:t4ugkdwwiy4nni4v7svyaisy/app.bsky.feed.post/3lsbbqvjyyc2r
#    Likes: 15, Reposts: 5, Replies: 0
# --------------------
# 13. Author: greenparty.org.uk (did:plc:txxvsciq7hiztf2xv37dccw2)
#    Date: 2025-06-23 09:35:12 UTC
#    Content: 'Nine years ago today the UK voted to leave the EU.  Since then our economy has shrunk, our creative industries have been damaged and our freedoms curt...'
#    URI: at://did:plc:txxvsciq7hiztf2xv37dccw2/app.bsky.feed.post/3lsbbqvhemw2p
#    Likes: 18, Reposts: 4, Replies: 0
# --------------------
# 14. Author: culturecrave.co (did:plc:vi2grzfali5xn5rh2ny2n4d4)
#    Date: 2025-06-23 09:35:08 UTC
#    Content: ''Batman: Arkham Knight' released 10 years ago today 🦇...'
#    URI: at://did:plc:vi2grzfali5xn5rh2ny2n4d4/app.bsky.feed.post/3lsbbqrhxu22d
#    Likes: 28, Reposts: 1, Replies: 1
# --------------------
# 15. Author: blupixl.bsky.social (did:plc:hhk6gcujlrrbkjgdpamscpgu)
#    Date: 2025-06-23 09:35:05 UTC
#    Content: 'cowgirl pen-pen...'
#    URI: at://did:plc:hhk6gcujlrrbkjgdpamscpgu/app.bsky.feed.post/3lsbbqpo3mt2i
#    Likes: 32, Reposts: 3, Replies: 0
# --------------------
# 16. Author: pisces.astrolis.com (did:plc:saieyrw2wcrdi3n5eqn6qopk)
#    Date: 2025-06-23 09:35:00 UTC
#    Content: '♓️ ❤️ That the Sun is spending his first full week in your romantic sector is a given, for his return over the weekend is the point when on the June s...'
#    URI: at://did:plc:saieyrw2wcrdi3n5eqn6qopk/app.bsky.feed.post/3lsbbqjuduv2d
#    Likes: 14, Reposts: 0, Replies: 0
# --------------------
# 17. Author: placepublique.bsky.social (did:plc:vgokjilonzbartfu2wce3qei)
#    Date: 2025-06-23 09:34:28 UTC
#    Content: '“Le 3e axe structurant, c’est de mettre la justice au coeur des politiques publiques. Nous voulons construire une société qui prend soin : des plus vu...'
#    URI: at://did:plc:vgokjilonzbartfu2wce3qei/app.bsky.feed.post/3lsbbpldpys2b
#    Likes: 12, Reposts: 5, Replies: 0
# --------------------
# 18. Author: albalbalba.bsky.social (did:plc:v6gdwtw4kjwmt7y7gaywkugd)
#    Date: 2025-06-23 09:34:20 UTC
#    Content: 'he decidido que me voy a desayunar a un bar vale?  ya he tenido suficiente. diréis alba haces lo que te da la gana  y tenéis razón.  deberíamos normal...'
#    URI: at://did:plc:v6gdwtw4kjwmt7y7gaywkugd/app.bsky.feed.post/3lsbbpdeg3c2d
#    Likes: 13, Reposts: 0, Replies: 0
# --------------------
# 19. Author: realbiscuitspaw.bsky.social (did:plc:dgmiuoyozdy7yqb5eg45iqxd)
#    Date: 2025-06-23 09:33:39 UTC
#    Content: '...'
#    URI: at://did:plc:dgmiuoyozdy7yqb5eg45iqxd/app.bsky.feed.post/3lsbbo4r3sk2k
#    Likes: 38, Reposts: 6, Replies: 3
# --------------------
# 20. Author: soozuk.bsky.social (did:plc:ifpzbxv4tqigkw66tz4yrojt)
#    Date: 2025-06-23 09:33:33 UTC
#    Content: 'Hahahahaha this is amazing coz she FUCKING LOVED being friends with Stephen Fry. He's EXACTLY the sort of twee faux-intellectual celeb that people lik...'
#    URI: at://did:plc:ifpzbxv4tqigkw66tz4yrojt/app.bsky.feed.post/3lsbbnwo6is2n
#    Likes: 92, Reposts: 12, Replies: 8
# --------------------
# 21. Author: uchidashusaku.bsky.social (did:plc:xcbnex4tdl2fa3bjopeviia2)
#    Date: 2025-06-23 09:33:11 UTC
#    Content: '鶏もも・ビーツ・なすのシチュー、ご飯 #青空ごはん部 #food #Atable 🍽️🍜...'
#    URI: at://did:plc:xcbnex4tdl2fa3bjopeviia2/app.bsky.feed.post/3lsbbnbghjk2i
#    Likes: 15, Reposts: 1, Replies: 1
# --------------------
# 22. Author: doraingrid.bsky.social (did:plc:u4fkvgm4aqrhtwov2jgdm72m)
#    Date: 2025-06-23 09:32:47 UTC
#    Content: 'The process of Nyx from Hades #timelapse #wip...'
#    URI: at://did:plc:u4fkvgm4aqrhtwov2jgdm72m/app.bsky.feed.post/3lsbbmkz3hs2v
#    Likes: 19, Reposts: 3, Replies: 0
# --------------------
# 23. Author: augustbembel.bsky.social (did:plc:dgtzzum5elrea7mcl6ql43ex)
#    Date: 2025-06-23 09:32:41 UTC
#    Content: 'bitte nicht verwechseln:  der scheiß bulle         ❌        der scheiß red bull ballert wels fort                       welsford ballert...'
#    URI: at://did:plc:dgtzzum5elrea7mcl6ql43ex/app.bsky.feed.post/3lsbbmetwus2u
#    Likes: 16, Reposts: 0, Replies: 2
# --------------------
# 24. Author: sirmichaeltake.bsky.social (did:plc:2va3thvzdrzpiem3dy76de2p)
#    Date: 2025-06-23 09:32:39 UTC
#    Content: 'Jill in the village shop has been baking a new carrot cake called The Bunker Buster to sell. It’s rather stodgy & tastes of yeast. Jill is worrying us...'
#    URI: at://did:plc:2va3thvzdrzpiem3dy76de2p/app.bsky.feed.post/3lsbbmcycoc2e
#    Likes: 22, Reposts: 2, Replies: 0
# --------------------
# 25. Author: isabelsantos.bsky.social (did:plc:uqnyrpls22pqbicmdkwnlvli)
#    Date: 2025-06-23 09:32:35 UTC
#    Content: '🤚🏻 I concur...'
#    URI: at://did:plc:uqnyrpls22pqbicmdkwnlvli/app.bsky.feed.post/3lsbbm7t7d22y
#    Likes: 17, Reposts: 4, Replies: 2
# --------------------
# 26. Author: kommtdraufan.bsky.social (did:plc:w23qqqui2km4xaro2xkygvd5)
#    Date: 2025-06-23 09:32:32 UTC
#    Content: 'Jaaaa! Endlich bald wieder neue Colleg*innen mit Altersweisheiten nerven.🥳...'
#    URI: at://did:plc:w23qqqui2km4xaro2xkygvd5/app.bsky.feed.post/3lsbbm4vxwc22
#    Likes: 18, Reposts: 0, Replies: 0
# --------------------
# 27. Author: netonyo.bsky.social (did:plc:x7fs3rwask2sj5xbnu3fukjj)
#    Date: 2025-06-23 09:32:24 UTC
#    Content: '애널에 들어가면 온 몸이 오싹오싹 ... ￼  #펠라 #애널 #뒤치기 #섹블 #커플 #신음 #암캐 #변녀 #주인님 #노예...'
#    URI: at://did:plc:x7fs3rwask2sj5xbnu3fukjj/app.bsky.feed.post/3lsbblv42u22y
#    Likes: 12, Reposts: 0, Replies: 1
# --------------------
# 28. Author: speld.nl (did:plc:qvsxr4wcx64iw4mvk5pyof57)
#    Date: 2025-06-23 11:32:24 UTC+02:00
#    Content: 'Dick Schoof oefent ‘wij betreuren het’ in 28 talen voor NAVO-top...'
#    URI: at://did:plc:qvsxr4wcx64iw4mvk5pyof57/app.bsky.feed.post/3lsbbly6a6h2e
#    Likes: 19, Reposts: 9, Replies: 0
# --------------------
# 29. Author: bigyellowsilly.bsky.social (did:plc:ehjotwfgklrytygj2x62y7hm)
#    Date: 2025-06-23 09:31:59 UTC
#    Content: 'how playing 3rd strike with my wife feels...'
#    URI: at://did:plc:ehjotwfgklrytygj2x62y7hm/app.bsky.feed.post/3lsbbl5kbr22x
#    Likes: 27, Reposts: 6, Replies: 0
# --------------------
# 30. Author: the-independent.com (did:plc:yc54nj2zlnqrdotewpkbrauy)
#    Date: 2025-06-23 09:31:44 UTC
#    Content: 'Our community largely agrees that Brexit was a mistake, but whether the UK should rejoin the EU remains deeply debated, with some calling it ‘a pipe d...'
#    URI: at://did:plc:yc54nj2zlnqrdotewpkbrauy/app.bsky.feed.post/3lsbbkpg3lj2s
#    Likes: 12, Reposts: 3, Replies: 1
# --------------------
# 31. Author: thisislevery.bsky.social (did:plc:oqk4srtbdu3a2srp3vy7oxvm)
#    Date: 2025-06-23 09:31:18 UTC
#    Content: 'Hab so viel Ahnung von Dating Apps, ich weiß bis heute nicht in welche Richtung man swiped...'
#    URI: at://did:plc:oqk4srtbdu3a2srp3vy7oxvm/app.bsky.feed.post/3lsbbjw7rcc26
#    Likes: 14, Reposts: 0, Replies: 4
# --------------------
# 32. Author: placepublique.bsky.social (did:plc:vgokjilonzbartfu2wce3qei)
#    Date: 2025-06-23 09:31:06 UTC
#    Content: '@raphaelglucksmann.bsky.social : "Ce que nous voulons, c’est une politique ambitieuse sur la question des salaires et sur celle des conditions de trav...'
#    URI: at://did:plc:vgokjilonzbartfu2wce3qei/app.bsky.feed.post/3lsbbjketd22b
#    Likes: 14, Reposts: 4, Replies: 0
# --------------------
# 33. Author: manner.bsky.social (did:plc:rhyrplcgkvmayoohbhmoojzo)
#    Date: 2025-06-23 09:31:01 UTC
#    Content: '今夜は牛ランプステーキよ〜 #青空ごはん部...'
#    URI: at://did:plc:rhyrplcgkvmayoohbhmoojzo/app.bsky.feed.post/3lsbbjgc6ns2f
#    Likes: 14, Reposts: 0, Replies: 0
# --------------------
# 34. Author: wired.com (did:plc:inz4fkbbp7ms3ixufw6xuvdi)
#    Date: 2025-06-23 09:30:39 UTC
#    Content: 'The Vera C. Rubin Observatory is poised to discover billions of new astronomical objects, revolutionizing understanding of everything from the history...'
#    URI: at://did:plc:inz4fkbbp7ms3ixufw6xuvdi/app.bsky.feed.post/3lsbbisfarg22
#    Likes: 45, Reposts: 7, Replies: 2
# --------------------
# 35. Author: wholesomememe.bsky.social (did:plc:3cuooxbpjwpetgmytd7lwjxb)
#    Date: 2025-06-23 09:30:23 UTC
#    Content: '...'
#    URI: at://did:plc:3cuooxbpjwpetgmytd7lwjxb/app.bsky.feed.post/3lsbbibtfwt2g
#    Likes: 26, Reposts: 5, Replies: 0
# --------------------
# 36. Author: romanpalace.bsky.social (did:plc:rvlxumizrapmnqf2r7ekxly2)
#    Date: 2025-06-23 09:30:20 UTC
#    Content: 'Birb from House of Paquius Proculus in Pompeii.  #MosaicMonday...'
#    URI: at://did:plc:rvlxumizrapmnqf2r7ekxly2/app.bsky.feed.post/3lsbbi6zbxc24
#    Likes: 25, Reposts: 6, Replies: 0
# --------------------
# 37. Author: koiso-tkhr.bsky.social (did:plc:djg4h7kncixfole5tu5i4vjy)
#    Date: 2025-06-23 09:30:19 UTC
#    Content: '今日の犬。  夕陽の中でジニアを見つめる。 ビタミンカラーだね🍋...'
#    URI: at://did:plc:djg4h7kncixfole5tu5i4vjy/app.bsky.feed.post/3lsbbi5jjn227
#    Likes: 18, Reposts: 2, Replies: 0
# --------------------
# 38. Author: renatebergmann.bsky.social (did:plc:apedndlcamijfgbxzfqdymws)
#    Date: 2025-06-23 09:30:16 UTC
#    Content: 'Gut und schön, aber ich könnte Ihnen Übungen zeigen, da knackt garantiert die Hüfte und der Rücken!...'
#    URI: at://did:plc:apedndlcamijfgbxzfqdymws/app.bsky.feed.post/3lsbbi2ysms2r
#    Likes: 17, Reposts: 1, Replies: 0
# --------------------
# 39. Author: gundampixel.bsky.social (did:plc:mwtj6ghumbe663lmtuu6vogh)
#    Date: 2025-06-23 09:30:04 UTC
#    Content: 'Not at all related to my previous post 😅, but an ESP Zaku Heat Hawk guitar is currently listed on Mercari! 🔥💸  Link: jp.mercari.com/item/m512383......'
#    URI: at://did:plc:mwtj6ghumbe663lmtuu6vogh/app.bsky.feed.post/3lsbbhpsqmk2d
#    Likes: 22, Reposts: 5, Replies: 1
# --------------------
# 40. Author: darthnudelholz.bsky.social (did:plc:3k4hbugkxudssv4gubgapjcz)
#    Date: 2025-06-23 09:29:56 UTC
#    Content: 'Der Mann: muss das Teil wirklich mit?  Ich: Egal, wie voll der Koffer auch ist, der Blåhaj muss mit! ☝️ (Alte Weisheit!)  Ich wollte den großen mitneh...'
#    URI: at://did:plc:3k4hbugkxudssv4gubgapjcz/app.bsky.feed.post/3lsbbhhgdqs2h
#    Likes: 12, Reposts: 0, Replies: 3
# --------------------
# 41. Author: elruli02.bsky.social (did:plc:fycnuphtqjhvimjy7gvksxgs)
#    Date: 2025-06-23 09:29:44 UTC
#    Content: 'La foto de moda está semana...'
#    URI: at://did:plc:fycnuphtqjhvimjy7gvksxgs/app.bsky.feed.post/3lsbbh426gk26
#    Likes: 14, Reposts: 0, Replies: 0
# --------------------
# 42. Author: kingkutrone.bsky.social (did:plc:ckqnnuecwx7is6b56p6ks3lv)
#    Date: 2025-06-23 09:29:43 UTC
#    Content: 'I told ya i had a big Aussie Arse 🤠🏀...'
#    URI: at://did:plc:ckqnnuecwx7is6b56p6ks3lv/app.bsky.feed.post/3lsbbh3vewc2m
#    Likes: 47, Reposts: 10, Replies: 1
# --------------------
# 43. Author: placepublique.bsky.social (did:plc:vgokjilonzbartfu2wce3qei)
#    Date: 2025-06-23 09:29:28 UTC
#    Content: '@raphaelglucksmann.bsky.social : "Les démocraties occidentales ont connu la stabilité en promettant aux citoyen-ne-s d'améliorer leurs conditions de v...'
#    URI: at://did:plc:vgokjilonzbartfu2wce3qei/app.bsky.feed.post/3lsbbgn6gsc2b
#    Likes: 14, Reposts: 4, Replies: 0
# --------------------
# 44. Author: apiln.bsky.social (did:plc:irlrdb4p2swljzcdjbhc54gd)
#    Date: 2025-06-23 09:29:21 UTC
#    Content: 'I’ll tell you what this is: WITCHERY  (Story via @swnslive.bsky.social)...'
#    URI: at://did:plc:irlrdb4p2swljzcdjbhc54gd/app.bsky.feed.post/3lsbbgg5jjs2g
#    Likes: 12, Reposts: 0, Replies: 3
# --------------------
# 45. Author: tontonpogo.bsky.social (did:plc:coo6o64yyqhuwp5n2yni6ogp)
#    Date: 2025-06-23 09:29:19 UTC
#    Content: 'être consternés par les zet et leur arrogance crasse et débile face à l'épistémologie...'
#    URI: at://did:plc:coo6o64yyqhuwp5n2yni6ogp/app.bsky.feed.post/3lsbbgelxls2i
#    Likes: 25, Reposts: 4, Replies: 1
# --------------------
# 46. Author: senorspilunco.bsky.social (did:plc:d44hrsqtvrm4k3h7bm7xypiz)
#    Date: 2025-06-23 09:29:05 UTC
#    Content: 'Meanwhile in a parallel Universe: Cem-Trail...'
#    URI: at://did:plc:d44hrsqtvrm4k3h7bm7xypiz/app.bsky.feed.post/3lsbbfxhhk22p
#    Likes: 16, Reposts: 1, Replies: 1
# --------------------
# 47. Author: oliver48.bsky.social (did:plc:zbhli4upddvlr6jihnlj46am)
#    Date: 2025-06-23 09:28:59 UTC
#    Content: 'A new parlour game for all the family ...  Watch BBC News together a point awarded for every lie, misinformation, biased language, lie by omission etc...'
#    URI: at://did:plc:zbhli4upddvlr6jihnlj46am/app.bsky.feed.post/3lsbbfr2vnc2j
#    Likes: 14, Reposts: 7, Replies: 0
# --------------------
# 48. Author: allchronology.com (did:plc:kcvr4dlanleiimco76aqophj)
#    Date: 2025-06-23 09:28:47 UTC
#    Content: '💥VIDEO: Trump’s $45 Million Parade Humiliates Him as Squeaky Tank Rolls Past Embarrassingly Empty Streets  Trump wanted his “Bastille Day moment.” Ins...'
#    URI: at://did:plc:kcvr4dlanleiimco76aqophj/app.bsky.feed.post/3lsbbffwt4c27
#    Likes: 13, Reposts: 3, Replies: 1
# --------------------
# 49. Author: ivanlefou.bsky.social (did:plc:f6daod27a27lj4bcviee2fsl)
#    Date: 2025-06-23 09:28:38 UTC
#    Content: 'Iran Où l'on apprend que: - l'effet des bombes est exagéré - on ne sait pas où est l'uranium - il existe des installations d'enrichissement intouchabl...'
#    URI: at://did:plc:f6daod27a27lj4bcviee2fsl/app.bsky.feed.post/3lsbbf5r25s2h
#    Likes: 13, Reposts: 2, Replies: 1
# --------------------
# 50. Author: wefail.bsky.social (did:plc:prcz4tsigtc2dsaw4xgbh6s3)
#    Date: 2025-06-23 09:28:35 UTC
#    Content: 'One of my Blue Sky prints off to a new home, £800 raised for ‪‪@medicalaidpal.bsky.social‬ up to now, still lots of prints left....'
#    URI: at://did:plc:prcz4tsigtc2dsaw4xgbh6s3/app.bsky.feed.post/3lsbbf2enfs2s
#    Likes: 14, Reposts: 3, Replies: 0
# --------------------
#
# --- RDD created from collected posts ---
# Number of partitions in RDD: 2
#
# Sample RDD elements:
#   1. {'uri': 'at://did:plc:xv2as7miy7ghje2htfynaqex/app.bsky.feed.post/3lsbbwheycs2h', 'cid': 'bafyreih5cb5c22damdejr4ilnw7c5fn4ftimkbmk7lxb74nnt2n4itpfwm', 'author_did': 'did:plc:xv2as7miy7ghje2htfynaqex', 'author_handle': 'aphclarkson.bsky.social', 'content': 'If the Khamenei regime does ever fall you end up with the question of who gets there hands on 400 kilograms of 60% enriched uranium whose location in Iran is currently unclear', 'created_at_iso': '2025-06-23T09:38:19.295Z', 'created_at_dt': datetime.datetime(2025, 6, 23, 9, 38, 19, 295000, tzinfo=datetime.timezone.utc), 'reply_count': 4, 'repost_count': 2, 'like_count': 17}
#   2. {'uri': 'at://did:plc:sykjce6e3ll5g6ev6evkcy3f/app.bsky.feed.post/3lsbbviw4ys2w', 'cid': 'bafyreif2mfucmub3sotndc3mmfhxm7xjtfbtvyraogh6ptnmwxq4knr22a', 'author_did': 'did:plc:sykjce6e3ll5g6ev6evkcy3f', 'author_handle': 'austinwalker.bsky.social', 'content': 'Had a great time at @narrascope.org this weekend, and as someone recovering from painful dentist stuff, was super grateful the conference was entirely hybrid with live streams for each talk so that I could go rest in the hotel occasionally without missing everything.', 'created_at_iso': '2025-06-23T09:37:47.349Z', 'created_at_dt': datetime.datetime(2025, 6, 23, 9, 37, 47, 349000, tzinfo=datetime.timezone.utc), 'reply_count': 0, 'repost_count': 0, 'like_count': 12}
#   3. {'uri': 'at://did:plc:hy5oozdsk27yctrzp4zuoqic/app.bsky.feed.post/3lsbbuoiocs2e', 'cid': 'bafyreidfakdldv3chcoe7apivgdabm2tzikucgtkqrfdpq4z5kjb3bhilm', 'author_did': 'did:plc:hy5oozdsk27yctrzp4zuoqic', 'author_handle': 'bernietranders.bsky.social', 'content': 'Happy 30th birthday to my gorgeous husband to be, @dpdormouse.bsky.social!\n\nHope you have a wonderful day, looking forward to celebrating a lifetime of birthdays with you.', 'created_at_iso': '2025-06-23T09:37:19.645Z', 'created_at_dt': datetime.datetime(2025, 6, 23, 9, 37, 19, 645000, tzinfo=datetime.timezone.utc), 'reply_count': 0, 'repost_count': 0, 'like_count': 23}
#   4. {'uri': 'at://did:plc:iezr5kzha5ycldknsa3jumiy/app.bsky.feed.post/3lsbbtpsims2j', 'cid': 'bafyreicq4kox5hudrcgxnzbcg4fl4cufufinpuuzodcgejgzdlbnbtfjjm', 'author_did': 'did:plc:iezr5kzha5ycldknsa3jumiy', 'author_handle': 'hideokojima.bsky.kojimaproductions.jp', 'content': '', 'created_at_iso': '2025-06-23T09:36:47.452Z', 'created_at_dt': datetime.datetime(2025, 6, 23, 9, 36, 47, 452000, tzinfo=datetime.timezone.utc), 'reply_count': 1, 'repost_count': 2, 'like_count': 13}
#   5. {'uri': 'at://did:plc:zy6sn6tkic24e6p52g2yh4zn/app.bsky.feed.post/3lsbbtni4qk2e', 'cid': 'bafyreic4x23tql5z4mlaulkm6zzai34nw4kvr6fgi5y2m5jwpsklvxtvey', 'author_did': 'did:plc:zy6sn6tkic24e6p52g2yh4zn', 'author_handle': 'rajandelman.bsky.social', 'content': 'JK like, "Joke\'s on you, I\'ve never had a friend, you dumb idiot"', 'created_at_iso': '2025-06-23T09:36:45.023Z', 'created_at_dt': datetime.datetime(2025, 6, 23, 9, 36, 45, 23000, tzinfo=datetime.timezone.utc), 'reply_count': 0, 'repost_count': 1, 'like_count': 17}

# %%
# Cell 5: Initialize Spark Session
from pyspark.sql import SparkSession

# Create a SparkSession (or get existing)
spark = SparkSession.builder \
    .appName("BlueskyPostAnalysis") \
    .getOrCreate()

print("SparkSession created.")
# Out:
# SparkSession created.
